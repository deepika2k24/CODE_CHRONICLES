# %% [markdown]
# ## Data Manipulation with Pandas

# %% [markdown]
# Pandas is a newer package built on top of NumPy, and provides an
# efficient implementation of a DataFrame. DataFrames are essentially multidimensional
# arrays with attached row and column labels, and often with heterogeneous types
# and/or missing data. As well as offering a convenient storage interface for
# labeled data, Pandas implements a number of powerful data
# operations familiar to users of both database frameworks and spreadsheet programs.
# Pandas, and in particular its <b> Series and DataFrame objects </b>,
# builds on the NumPy array structure and provides efficient access to messy data
# and helps in “data munging” tasks that occupy much of a data scientist’s time.

# %%
import pandas as pd  # pandas : panel data , python data analysis

# %% [markdown]
# ###### Pandas concatenate

# %%
#pd.concat() can be used for a simple concatenation of 
# Series or DataFrame objects,
ser1 = pd.Series(['A', 'B', 'C'], index=[1, 2, 3])
ser2 = pd.Series(['D', 'E', 'F'], index=[4, 5, 6])
print(ser1)
print(ser2)
pd.concat([ser1, ser2],axis=1)
# Out:
# 1    A
# 2    B
# 3    C
# dtype: object
# 4    D
# 5    E
# 6    F
# dtype: object
#      0    1
# 1    A  NaN
# 2    B  NaN
# 3    C  NaN
# 4  NaN    D
# 5  NaN    E
# 6  NaN    F

# %%
def make_df(cols, ind):
    """Quickly make a DataFrame"""
    data = {c:[str(c) + str(i) for i in ind] for c in cols}
    print(data)
    return pd.DataFrame(data, ind)

# %%
df1 = make_df('AB', [1, 2])
df2 = make_df('AB', [3, 4])
print(df1); print(df2); print(pd.concat([df1, df2],axis=1))
# Out:
# {'A': ['A1', 'A2'], 'B': ['B1', 'B2']}
# {'A': ['A3', 'A4'], 'B': ['B3', 'B4']}
#     A   B
# 1  A1  B1
# 2  A2  B2
#     A   B
# 3  A3  B3
# 4  A4  B4
#      A    B    A    B
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3  NaN  NaN   A3   B3
# 4  NaN  NaN   A4   B4

# %%
"""By default, the concatenation takes place row-wise within the DataFrame 
(i.e.,axis=0). Like np.concatenate, pd.concat allows specification 
of an axis along which concatenation will take place."""
df3 = make_df('AB', [0, 1])
df4 = make_df('CD', [0, 1])
print(df3); print(df4); print(pd.concat([df3, df4],axis=1))
# Out:
# {'A': ['A0', 'A1'], 'B': ['B0', 'B1']}
# {'C': ['C0', 'C1'], 'D': ['D0', 'D1']}
#     A   B
# 0  A0  B0
# 1  A1  B1
#     C   D
# 0  C0  D0
# 1  C1  D1
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1

# %% [markdown]
# ###### Duplicate indices

# %%
"""One important difference between np.concatenate and pd.concat is that Pandas
concatenation preserves indices, even if the result will have duplicate indices!
Consider this simple example:"""
x = make_df('AB', [0, 1])
y = make_df('AB', [2, 3])
y.index = x.index # make duplicate indices!
print(x); print(y); print(pd.concat([x, y]))
# Out:
# {'A': ['A0', 'A1'], 'B': ['B0', 'B1']}
# {'A': ['A2', 'A3'], 'B': ['B2', 'B3']}
#     A   B
# 0  A0  B0
# 1  A1  B1
#     A   B
# 0  A2  B2
# 1  A3  B3
#     A   B
# 0  A0  B0
# 1  A1  B1
# 0  A2  B2
# 1  A3  B3

# %% [markdown]
# ###### Caching the error

# %%
"""Catching the repeats as an error. If you’d like to simply verify that the indices in the
result of pd.concat() do not overlap, you can specify the verify_integrity flag.
With this set to True, the concatenation will raise an exception if there are duplicate
indices. Here is an example, where for clarity we’ll catch and print the error message:"""
try:
    pd.concat([x, y], verify_integrity=True)
except ValueError as e:
    print("ValueError:", e)
# Out:
# ValueError: Indexes have overlapping values: Index([0, 1], dtype='int64')

# %% [markdown]
# ###### Ignoring the Index

# %%
"""Sometimes the index itself does not matter, and you would prefer
it to simply be ignored. You can specify this option using the ignore_index flag. With
this set to True, the concatenation will create a new integer index for the resulting
Series:"""
print(x); print(y); print(pd.concat([x, y], ignore_index=True))
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
#     A   B
# 0  A2  B2
# 1  A3  B3
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %% [markdown]
# ###### Adding MultiIndex keys

# %%
print(x); print(y); print(pd.concat([x, y], keys=['x', 'y']))
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
#     A   B
# 0  A2  B2
# 1  A3  B3
#       A   B
# x 0  A0  B0
#   1  A1  B1
# y 0  A2  B2
#   1  A3  B3

# %%
"""Concatenation with joins
In the simple examples we just looked at, we were mainly concatenating DataFrames
with shared column names. In practice, data from different sources might have different
sets of column names, and pd.concat offers several options in this case. Consider
the concatenation of the following two DataFrames, which have some (but not all!)
columns in common:"""
df5 = make_df('ABC', [1, 2])
df6 = make_df('BCD', [3, 4])
print(df5); print(df6); print(pd.concat([df5, df6]))
# Out:
# {'A': ['A1', 'A2'], 'B': ['B1', 'B2'], 'C': ['C1', 'C2']}
# {'B': ['B3', 'B4'], 'C': ['C3', 'C4'], 'D': ['D3', 'D4']}
#     A   B   C
# 1  A1  B1  C1
# 2  A2  B2  C2
#     B   C   D
# 3  B3  C3  D3
# 4  B4  C4  D4
#      A   B   C    D
# 1   A1  B1  C1  NaN
# 2   A2  B2  C2  NaN
# 3  NaN  B3  C3   D3
# 4  NaN  B4  C4   D4

# %%
print(df5); print(df6);
print(pd.concat([df5, df6], join='inner'))
# Out:
#     A   B   C
# 1  A1  B1  C1
# 2  A2  B2  C2
#     B   C   D
# 3  B3  C3  D3
# 4  B4  C4  D4
#     B   C
# 1  B1  C1
# 2  B2  C2
# 3  B3  C3
# 4  B4  C4

# %% [markdown]
# ###### Combining Datasets: Merge and Join
# One essential feature offered by Pandas is its high-performance, <b> in-memory join and
# merge operations</b>. If you have ever worked with databases, you should be familiar
# with this type of data interaction. The main interface for this is the pd.merge function,

# %%
#Categories of Join
"""The pd.merge() function implements a number of types of joins: the one-to-one,
many-to-one, and many-to-many joins. All three types of joins are accessed via an
identical call to the pd.merge() interface; the type of join performed depends on the
form of the input data. columns made as index """
#One-to-one joins
df1 = pd.DataFrame({'employee': ['Bob', 'Jake', 'Lisa', 'Sue'],
                    'group': ['Accounting', 'Engineering', 'Engineering', 'HR']})
df2 = pd.DataFrame({'employee': ['Lisa', 'Bob', 'Jake', 'Sue'],
                    'hire_date': [2004, 2008, 2012, 2014]})
print(df1); print(df2)
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
#   employee  hire_date
# 0     Lisa       2004
# 1      Bob       2008
# 2     Jake       2012
# 3      Sue       2014

# %%
#To combine df1 and df2
df3 = pd.merge(df1, df2)
df3
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014

# %%
#Many-to-one joins
df4 = pd.DataFrame({'group': ['Accounting', 'Engineering', 'HR'],
                    'supervisor': ['Carly', 'Guido', 'Steve']})
print(df3); print(df4); print(pd.merge(df3, df4))
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014
#          group supervisor
# 0   Accounting      Carly
# 1  Engineering      Guido
# 2           HR      Steve
#   employee        group  hire_date supervisor
# 0      Bob   Accounting       2008      Carly
# 1     Jake  Engineering       2012      Guido
# 2     Lisa  Engineering       2004      Guido
# 3      Sue           HR       2014      Steve

# %%
#Many-to-many joins
df5 = pd.DataFrame({'group': ['Accounting', 'Accounting',
                              'Engineering', 'Engineering', 'HR', 'HR'],
                    'skills': ['math', 'spreadsheets', 'coding', 'linux',
                               'spreadsheets', 'organization']})
print(df1); print(df5); print(pd.merge(df1, df5))
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
#          group        skills
# 0   Accounting          math
# 1   Accounting  spreadsheets
# 2  Engineering        coding
# 3  Engineering         linux
# 4           HR  spreadsheets
# 5           HR  organization
#   employee        group        skills
# 0      Bob   Accounting          math
# 1      Bob   Accounting  spreadsheets
# 2     Jake  Engineering        coding
# 3     Jake  Engineering         linux
# 4     Lisa  Engineering        coding
# 5     Lisa  Engineering         linux
# 6      Sue           HR  spreadsheets
# 7      Sue           HR  organization

# %%
#Specification of the Merge Key *merge inner join *concat outer join
#The on keyword default merge perfoerms imnner join
#This option works only if both the left and right DataFrames have the specified column name.
print(df1); print(df2); print(pd.merge(df1, df2, on='employee'))
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
#   employee  hire_date
# 0     Lisa       2004
# 1      Bob       2008
# 2     Jake       2012
# 3      Sue       2014
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014

# %%
df3 = pd.DataFrame({'name':['Bob', 'Jake', 'Lisa', 'Sue'],
                    'salary': [70000, 80000, 120000, 90000]})
print(df2); print(df3); print(pd.merge(df2, df3, left_on='employee',right_on='name'))
# Out:
#   employee  hire_date
# 0     Lisa       2004
# 1      Bob       2008
# 2     Jake       2012
# 3      Sue       2014
#    name  salary
# 0   Bob   70000
# 1  Jake   80000
# 2  Lisa  120000
# 3   Sue   90000
#   employee  hire_date  name  salary
# 0     Lisa       2004  Lisa  120000
# 1      Bob       2008   Bob   70000
# 2     Jake       2012  Jake   80000
# 3      Sue       2014   Sue   90000

# %%
"""The result has a redundant column that we can drop if desired—for example, by
using the drop() method of DataFrames:"""
print(pd.merge(df2, df3, left_on='employee',right_on='name').drop('name',axis=1))
# Out:
#   employee  hire_date  salary
# 0     Lisa       2004  120000
# 1      Bob       2008   70000
# 2     Jake       2012   80000
# 3      Sue       2014   90000

# %%
#The left_index and right_index keywords
df1a = df1.set_index('employee')
df2a = df2.set_index('employee')
print(df1a); print(df2a)
# Out:
#                 group
# employee
# Bob        Accounting
# Jake      Engineering
# Lisa      Engineering
# Sue                HR
#           hire_date
# employee
# Lisa           2004
# Bob            2008
# Jake           2012
# Sue            2014

# %%
print(pd.merge(df1a, df2a, left_index=True, right_index=True))
# Out:
#                 group  hire_date
# employee
# Bob        Accounting       2008
# Jake      Engineering       2012
# Lisa      Engineering       2004
# Sue                HR       2014

# %%
"""For convenience, DataFrames implement the join() method, which performs a
merge that defaults to joining on indices:"""
print(df1a); print(df2a); print(df1a.join(df2a))
# Out:
#                 group
# employee
# Bob        Accounting
# Jake      Engineering
# Lisa      Engineering
# Sue                HR
#           hire_date
# employee
# Lisa           2004
# Bob            2008
# Jake           2012
# Sue            2014
#                 group  hire_date
# employee
# Bob        Accounting       2008
# Jake      Engineering       2012
# Lisa      Engineering       2004
# Sue                HR       2014

# %%
"""If you’d like to mix indices and columns, you can combine left_index with right_on
or left_on with right_index to get the desired behavior:"""
print(df1a); print(df3);
print(pd.merge(df1a, df3, left_index=True, right_on='name'))
# Out:
#                 group
# employee
# Bob        Accounting
# Jake      Engineering
# Lisa      Engineering
# Sue                HR
#    name  salary
# 0   Bob   70000
# 1  Jake   80000
# 2  Lisa  120000
# 3   Sue   90000
#          group  name  salary
# 0   Accounting   Bob   70000
# 1  Engineering  Jake   80000
# 2  Engineering  Lisa  120000
# 3           HR   Sue   90000

# %% [markdown]
# ###### Specifying Set Arithmetic for Joins

# %%
#by default inner join -merge
df6 = pd.DataFrame({'name': ['Peter', 'Paul', 'Mary'],
'food': ['fish', 'beans', 'bread']},
columns=['name', 'food'])
df7 = pd.DataFrame({'name': ['Mary', 'Joseph'],
'drink': ['wine', 'beer']},
columns=['name', 'drink'])
print(df6); print(df7); print(pd.merge(df6, df7))
# Out:
#     name   food
# 0  Peter   fish
# 1   Paul  beans
# 2   Mary  bread
#      name drink
# 0    Mary  wine
# 1  Joseph  beer
#    name   food drink
# 0  Mary  bread  wine

# %%
"""We can specify this explicitly using the how keyword,
which defaults to 'inner':"""
pd.merge(df6, df7, how='inner')
# Out:
#    name   food drink
# 0  Mary  bread  wine

# %%
"""Other options for the how keyword are 'outer', 'left', and 'right'. An outer join
returns a join over the union of the input columns, and fills in all missing values with
NAs:"""
print(df6); print(df7); print(pd.merge(df6, df7, how='outer'))
# Out:
#     name   food
# 0  Peter   fish
# 1   Paul  beans
# 2   Mary  bread
#      name drink
# 0    Mary  wine
# 1  Joseph  beer
#      name   food drink
# 0  Joseph    NaN  beer
# 1    Mary  bread  wine
# 2    Paul  beans   NaN
# 3   Peter   fish   NaN

# %%
print(df6); print(df7); print(pd.merge(df6, df7, how='left'))
# Out:
#     name   food
# 0  Peter   fish
# 1   Paul  beans
# 2   Mary  bread
#      name drink
# 0    Mary  wine
# 1  Joseph  beer
#     name   food drink
# 0  Peter   fish   NaN
# 1   Paul  beans   NaN
# 2   Mary  bread  wine

# %%
print(df6); print(df7); print(pd.merge(df6, df7, how='right'))
# Out:
#     name   food
# 0  Peter   fish
# 1   Paul  beans
# 2   Mary  bread
#      name drink
# 0    Mary  wine
# 1  Joseph  beer
#      name   food drink
# 0    Mary  bread  wine
# 1  Joseph    NaN  beer

# %% [markdown]
# ###### Overlapping Column Names: The suffixes Keyword

# %%
df8 = pd.DataFrame({'name': ['Bob', 'Jake', 'Lisa', 'Sue'],
'rank': [1, 2, 3, 4]})
df9 = pd.DataFrame({'name': ['Bob', 'Jake', 'Lisa', 'Sue'],
'rank': [3, 1, 4, 2]})
print(df8); print(df9); print(pd.merge(df8, df9,on="rank"))
# Out:
#    name  rank
# 0   Bob     1
# 1  Jake     2
# 2  Lisa     3
# 3   Sue     4
#    name  rank
# 0   Bob     3
# 1  Jake     1
# 2  Lisa     4
# 3   Sue     2
#   name_x  rank name_y
# 0    Bob     1   Jake
# 1   Jake     2    Sue
# 2   Lisa     3    Bob
# 3    Sue     4   Lisa

# %%
print(df8); print(df9);
print(pd.merge(df8, df9, on="name", suffixes=["_L", "_R"]))
# Out:
#    name  rank
# 0   Bob     1
# 1  Jake     2
# 2  Lisa     3
# 3   Sue     4
#    name  rank
# 0   Bob     3
# 1  Jake     1
# 2  Lisa     4
# 3   Sue     2
#    name  rank_L  rank_R
# 0   Bob       1       3
# 1  Jake       2       1
# 2  Lisa       3       4
# 3   Sue       4       2

# %%
#df.dropna()

# %%
#US States Data
pop = pd.read_csv('state-population.csv')
areas = pd.read_csv('state-areas.csv')
abbrevs = pd.read_csv('state-abbrevs.csv')

# %%
pop.head()
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %%
pop_df = pd.get_dummies(pop, columns=['ages'], dtype='int',drop_first=True)
pop_df
# Out:
#      state/region  year   population  ages_under18
# 0              AL  2012    1117489.0             1
# 1              AL  2012    4817528.0             0
# 2              AL  2010    1130966.0             1
# 3              AL  2010    4785570.0             0
# 4              AL  2011    1125763.0             1
# ...           ...   ...          ...           ...
# 2539          USA  2010  309326295.0             0
# 2540          USA  2011   73902222.0             1
# 2541          USA  2011  311582564.0             0
# 2542          USA  2012   73708179.0             1
# 2543          USA  2012  313873685.0             0
#
# [2544 rows x 4 columns]

# %%
areas.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %%
areas.shape[0]
# Out:
# 52

# %%
abbrevs.head()
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
"""Query: Given this information, say we want to compute a relatively straightforward result:
rank US states and territories by their 2010 population density."""
merged = pd.merge(pop, abbrevs, how='outer',
left_on='state/region', right_on='abbreviation').drop('abbreviation',axis=1)
merged
# Out:
#      state/region     ages  year  population    state
# 0              AK    total  1990    553290.0   Alaska
# 1              AK  under18  1990    177502.0   Alaska
# 2              AK    total  1992    588736.0   Alaska
# 3              AK  under18  1991    182180.0   Alaska
# 4              AK  under18  1992    184878.0   Alaska
# ...           ...      ...   ...         ...      ...
# 2539           WY  under18  1993    137458.0  Wyoming
# 2540           WY    total  1991    459260.0  Wyoming
# 2541           WY  under18  1991    136720.0  Wyoming
# 2542           WY  under18  1990    136078.0  Wyoming
# 2543           WY    total  1990    453690.0  Wyoming
#
# [2544 rows x 5 columns]

# %%
merged.isnull().sum()
# Out:
# state/region     0
# ages             0
# year             0
# population      20
# state           96
# dtype: int64

# %%
"""It appears that all the null population values are from Puerto Rico prior to the year
2000; this is likely due to this data not being available from the original source."""

"""The statement filters the merged DataFrame for rows where the ‘population’ 
column contains missing values (NaN) and returns the first 5 rows of this filtered DataFrame.."""

merged[merged['population'].isnull()].head()
# Out:
#      state/region     ages  year  population state
# 1872           PR  under18  1990         NaN   NaN
# 1873           PR    total  1990         NaN   NaN
# 1874           PR    total  1991         NaN   NaN
# 1875           PR  under18  1991         NaN   NaN
# 1876           PR    total  1993         NaN   NaN

# %%
"""we see also that some of the new state entries are also null, which
means that there was no corresponding entry in the abbrevs key! Let’s figure out
which regions lack this match"""

"""The statement filters the merged DataFrame for rows where the ‘state’ column 
has missing values, and then retrieves the unique values from the ‘state/region’column in those filtered rows. 
This will give a list of unique state/region codes or identifiers that correspond to missing state information."""

merged.loc[merged['state'].isnull(), 'state/region'].unique()
# Out:
# array(['PR', 'USA'], dtype=object)

# %%
merged.loc[merged['state/region'] == 'PR', 'state'] = 'Puerto Rico'
merged.loc[merged['state/region'] == 'USA', 'state'] = 'United States'

# %%
merged.isnull().any()
# Out:
# state/region    False
# ages            False
# year            False
# population       True
# state           False
# dtype: bool

# %%
areas.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %%
merged.head()
# Out:
#   state/region     ages  year  population   state
# 0           AK    total  1990    553290.0  Alaska
# 1           AK  under18  1990    177502.0  Alaska
# 2           AK    total  1992    588736.0  Alaska
# 3           AK  under18  1991    182180.0  Alaska
# 4           AK  under18  1992    184878.0  Alaska

# %%
pd.set_option('display.max_rows', 3000)

# %%
"""Now we can merge the result with the area data using a similar procedure. Examining
our results, we will want to join on the state column in both:"""
final = pd.merge(merged, areas, on='state', how='left')
final
# Out:
#      state/region     ages  year   population                 state  \
# 0              AK    total  1990     553290.0                Alaska
# 1              AK  under18  1990     177502.0                Alaska
# 2              AK    total  1992     588736.0                Alaska
# 3              AK  under18  1991     182180.0                Alaska
# 4              AK  under18  1992     184878.0                Alaska
# 5              AK    total  1994     603308.0                Alaska
# 6              AK  under18  1994     187439.0                Alaska
# 7              AK    total  1991     570193.0                Alaska
# 8              AK    total  1993     599434.0                Alaska
# 9              AK  under18  1993     187190.0                Alaska
# 10             AK    total  1995     604412.0                Alaska
# 11             AK  under18  1995     184990.0                Alaska
# 12             AK    total  1996     608569.0                Alaska
# 13             AK  under18  1996     185360.0                Alaska
# 14             AK  under18  1997     188280.0                Alaska
# 15             AK  under18  1998     192636.0                Alaska
# 16             AK    total  1998     619933.0                Alaska
# 17             AK    total  1997     612968.0                Alaska
# 18             AK  under18  1999     191422.0                Alaska
# 19             AK    total  1999     624779.0                Alaska
# 20             AK    total  2000     627963.0                Alaska
# 21             AK  under18  2000     190615.0                Alaska
# 22             AK    total  2001     633714.0                Alaska
# 23             AK  under18  2001     188771.0                Alaska
# 24             AK    total  2002     642337.0                Alaska
# 25             AK  under18  2002     188482.0                Alaska
# 26             AK    total  2003     648414.0                Alaska
# 27             AK  under18  2003     186843.0                Alaska
# 28             AK    total  2004     659286.0                Alaska
# 29             AK  under18  2004     186335.0                Alaska
# 30             AK    total  2005     666946.0                Alaska
# 31             AK  under18  2005     185304.0                Alaska
# 32             AK    total  2006     675302.0                Alaska
# 33             AK  under18  2006     185580.0                Alaska
# 34             AK    total  2007     680300.0                Alaska
# 35             AK  under18  2007     184344.0                Alaska
# 36             AK    total  2008     687455.0                Alaska
# 37             AK  under18  2008     183124.0                Alaska
# 38             AK  under18  2013     188132.0                Alaska
# 39             AK    total  2013     735132.0                Alaska
# 40             AK    total  2009     698895.0                Alaska
# 41             AK  under18  2009     186351.0                Alaska
# 42             AK  under18  2010     187902.0                Alaska
# 43             AK    total  2010     713868.0                Alaska
# 44             AK  under18  2011     188329.0                Alaska
# 45             AK    total  2011     723375.0                Alaska
# 46             AK  under18  2012     188162.0                Alaska
# 47             AK    total  2012     730307.0                Alaska
# 48             AL  under18  2012    1117489.0               Alabama
# 49             AL    total  2012    4817528.0               Alabama
# 50             AL  under18  2010    1130966.0               Alabama
# 51             AL    total  2010    4785570.0               Alabama
# 52             AL  under18  2011    1125763.0               Alabama
# 53             AL    total  2011    4801627.0               Alabama
# 54             AL    total  2009    4757938.0               Alabama
# 55             AL  under18  2009    1134192.0               Alabama
# 56             AL  under18  2013    1111481.0               Alabama
# 57             AL    total  2013    4833722.0               Alabama
# 58             AL    total  2007    4672840.0               Alabama
# 59             AL  under18  2007    1132296.0               Alabama
# 60             AL    total  2008    4718206.0               Alabama
# 61             AL  under18  2008    1134927.0               Alabama
# 62             AL    total  2005    4569805.0               Alabama
# 63             AL  under18  2005    1117229.0               Alabama
# 64             AL    total  2006    4628981.0               Alabama
# 65             AL  under18  2006    1126798.0               Alabama
# 66             AL    total  2004    4530729.0               Alabama
# 67             AL  under18  2004    1113662.0               Alabama
# 68             AL    total  2003    4503491.0               Alabama
# 69             AL  under18  2003    1113083.0               Alabama
# 70             AL    total  2001    4467634.0               Alabama
# 71             AL  under18  2001    1120409.0               Alabama
# 72             AL    total  2002    4480089.0               Alabama
# 73             AL  under18  2002    1116590.0               Alabama
# 74             AL  under18  1999    1121287.0               Alabama
# 75             AL    total  1999    4430141.0               Alabama
# 76             AL    total  2000    4452173.0               Alabama
# 77             AL  under18  2000    1122273.0               Alabama
# 78             AL    total  1998    4404701.0               Alabama
# 79             AL  under18  1998    1118252.0               Alabama
# 80             AL  under18  1997    1122893.0               Alabama
# 81             AL    total  1997    4367935.0               Alabama
# 82             AL    total  1996    4331103.0               Alabama
# 83             AL    total  1995    4296800.0               Alabama
# 84             AL  under18  1995    1110553.0               Alabama
# 85             AL  under18  1996    1112092.0               Alabama
# 86             AL    total  1994    4260229.0               Alabama
# 87             AL    total  1993    4214202.0               Alabama
# 88             AL  under18  1993    1085606.0               Alabama
# 89             AL  under18  1994    1097180.0               Alabama
# 90             AL  under18  1992    1072873.0               Alabama
# 91             AL    total  1992    4154014.0               Alabama
# 92             AL    total  1991    4099156.0               Alabama
# 93             AL  under18  1991    1060794.0               Alabama
# 94             AL  under18  1990    1050041.0               Alabama
# 95             AL    total  1990    4050055.0               Alabama
# 96             AR  under18  1990     620933.0              Arkansas
# 97             AR    total  1990    2356586.0              Arkansas
# 98             AR    total  1991    2383144.0              Arkansas
# 99             AR  under18  1991     626212.0              Arkansas
# 100            AR  under18  1992     638269.0              Arkansas
# 101            AR    total  1992    2415984.0              Arkansas
# 102            AR  under18  1994     653842.0              Arkansas
# 103            AR    total  1994    2494019.0              Arkansas
# 104            AR    total  1993    2456303.0              Arkansas
# 105            AR  under18  1993     643474.0              Arkansas
# 106            AR  under18  1995     667671.0              Arkansas
# 107            AR    total  1995    2535399.0              Arkansas
# 108            AR  under18  1996     677912.0              Arkansas
# 109            AR    total  1996    2572109.0              Arkansas
# 110            AR  under18  1998     683637.0              Arkansas
# 111            AR    total  1997    2601091.0              Arkansas
# 112            AR  under18  1997     680203.0              Arkansas
# 113            AR    total  1998    2626289.0              Arkansas
# 114            AR    total  2000    2678588.0              Arkansas
# 115            AR  under18  2000     680378.0              Arkansas
# 116            AR  under18  1999     681940.0              Arkansas
# 117            AR    total  1999    2651860.0              Arkansas
# 118            AR    total  2002    2705927.0              Arkansas
# 119            AR  under18  2002     678798.0              Arkansas
# 120            AR    total  2001    2691571.0              Arkansas
# 121            AR  under18  2001     679606.0              Arkansas
# 122            AR    total  2004    2749686.0              Arkansas
# 123            AR  under18  2004     683166.0              Arkansas
# 124            AR    total  2003    2724816.0              Arkansas
# 125            AR  under18  2003     679579.0              Arkansas
# 126            AR    total  2006    2821761.0              Arkansas
# 127            AR  under18  2006     697842.0              Arkansas
# 128            AR    total  2005    2781097.0              Arkansas
# 129            AR  under18  2005     689787.0              Arkansas
# 130            AR    total  2008    2874554.0              Arkansas
# 131            AR  under18  2008     705725.0              Arkansas
# 132            AR    total  2007    2848650.0              Arkansas
# 133            AR  under18  2007     702737.0              Arkansas
# 134            AR    total  2009    2896843.0              Arkansas
# 135            AR  under18  2009     707886.0              Arkansas
# 136            AR  under18  2013     709866.0              Arkansas
# 137            AR    total  2013    2959373.0              Arkansas
# 138            AR  under18  2011     710576.0              Arkansas
# 139            AR    total  2011    2938506.0              Arkansas
# 337            DC    total  2012     633427.0  District of Columbia
# 338            DC  under18  2011     103906.0  District of Columbia
# 339            DC    total  2011     619624.0  District of Columbia
# 340            DC  under18  2010     101309.0  District of Columbia
# 341            DC    total  2010     605125.0  District of Columbia
# 342            DC  under18  2013     111474.0  District of Columbia
# 343            DC    total  2013     646449.0  District of Columbia
# 344            DC    total  2009     592228.0  District of Columbia
# 345            DC  under18  2009     102098.0  District of Columbia
# 346            DC    total  2007     574404.0  District of Columbia
# 347            DC  under18  2007     104126.0  District of Columbia
# 348            DC    total  2008     580236.0  District of Columbia
# 349            DC  under18  2008     102257.0  District of Columbia
# 350            DC    total  2005     567136.0  District of Columbia
# 351            DC  under18  2005     107187.0  District of Columbia
# 352            DC    total  2006     570681.0  District of Columbia
# 353            DC  under18  2006     105651.0  District of Columbia
# 354            DC    total  2003     568502.0  District of Columbia
# 355            DC  under18  2003     111403.0  District of Columbia
# 356            DC    total  2004     567754.0  District of Columbia
# 357            DC  under18  2004     109756.0  District of Columbia
# 358            DC    total  2001     574504.0  District of Columbia
# 359            DC  under18  2001     114625.0  District of Columbia
# 360            DC    total  2002     573158.0  District of Columbia
# 361            DC  under18  2002     113822.0  District of Columbia
# 362            DC    total  1999     570220.0  District of Columbia
# 363            DC  under18  1999     115003.0  District of Columbia
# 364            DC    total  2000     572046.0  District of Columbia
# 365            DC  under18  2000     114503.0  District of Columbia
# 366            DC  under18  1998     113839.0  District of Columbia
# 367            DC    total  1998     565232.0  District of Columbia
# 368            DC  under18  1997     119531.0  District of Columbia
# 369            DC    total  1997     567739.0  District of Columbia
# 370            DC  under18  1996     121210.0  District of Columbia
# 371            DC    total  1996     572379.0  District of Columbia
# 372            DC    total  1995     580519.0  District of Columbia
# 373            DC  under18  1995     123620.0  District of Columbia
# 374            DC    total  1993     595302.0  District of Columbia
# 375            DC  under18  1993     120471.0  District of Columbia
# 376            DC  under18  1994     122170.0  District of Columbia
# 377            DC    total  1994     589240.0  District of Columbia
# 378            DC    total  1991     600870.0  District of Columbia
# 379            DC  under18  1991     116825.0  District of Columbia
# 380            DC  under18  1992     118636.0  District of Columbia
# 381            DC    total  1992     597567.0  District of Columbia
# 382            DC  under18  1990     112632.0  District of Columbia
# 383            DC    total  1990     605321.0  District of Columbia
# 384            DE  under18  1990     165628.0              Delaware
# 385            DE    total  1990     669567.0              Delaware
# 386            DE  under18  1992     174166.0              Delaware
# 387            DE    total  1992     694927.0              Delaware
# 388            DE    total  1991     683080.0              Delaware
# 389            DE  under18  1991     169910.0              Delaware
# 390            DE    total  1994     717545.0              Delaware
# 391            DE  under18  1994     180833.0              Delaware
# 392            DE    total  1993     706378.0              Delaware
# 393            DE  under18  1993     176916.0              Delaware
# 394            DE  under18  1995     181736.0              Delaware
# 395            DE    total  1995     729735.0              Delaware
# 396            DE    total  1996     740978.0              Delaware
# 397            DE  under18  1996     184021.0              Delaware
# 398            DE  under18  1997     186607.0              Delaware
# 399            DE    total  1997     751487.0              Delaware
isnull().any()
# Out:
# state/region     False
# ages             False
# year             False
# population        True
# state            False
# area (sq. mi)     True
# dtype: bool

# %%
"""This statement filters the final DataFrame for rows where the ‘area (sq. mi)’ column has missing values and returns the unique values from the ‘state’ column in those rows. 
This will give a list of unique states that have missing data in the ‘area (sq. mi)’ field."""
final['state'][final['area (sq. mi)'].isnull()].unique()
# Out:
# array(['United States'], dtype=object)

# %%
"""We see that our areas DataFrame does not contain the area of the United States as a
whole. We could insert the appropriate value (using the sum of all state areas, for
instance), but in this case we’ll just drop the null values because the population density
of the entire United States is not relevant to our current discussion:"""
final.dropna(inplace=True)
final.head()
# Out:
#   state/region     ages  year  population   state  area (sq. mi)
# 0           AK    total  1990    553290.0  Alaska       656425.0
# 1           AK  under18  1990    177502.0  Alaska       656425.0
# 2           AK    total  1992    588736.0  Alaska       656425.0
# 3           AK  under18  1991    182180.0  Alaska       656425.0
# 4           AK  under18  1992    184878.0  Alaska       656425.0

# %%
# Calculate correlation matrix
correlation_matrix = final[['population', 'area (sq. mi)']].corr()

# Generate a heatmap for the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix,annot=True, linewidths=0.5,cmap='viridis')
plt.title('Heatmap of Population, Area Correlation')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 5
#       2 correlation_matrix = final[['population', 'area (sq. mi)']].corr()
#       4 # Generate a heatmap for the correlation matrix
# ----> 5 plt.figure(figsize=(8, 6))
#       6 sns.heatmap(correlation_matrix,annot=True, linewidths=0.5,cmap='viridis')
#       7 plt.title('Heatmap of Population, Area Correlation')
#
# NameError: name 'plt' is not defined

# %%
# !pip install numexpr

# %%
#data2010 = final[(final.year == 2010) & (final.ages == 'total')]
data2010 = final.query("year == 2010 & ages == 'total'")
data2010.head()

# %%
data2010.set_index('state', inplace=True)
density = data2010['population'] / data2010['area (sq. mi)']
density.sort_values(ascending=False, inplace=True)
density.head()

# %%
#end list
density.tail()

# %% [markdown]
# ###### Aggregation and Grouping

# %%
#Planets Data
"""It gives information on planets that astronomers
have discovered around other stars (known as extrasolar planets or exoplanets for
short). It can be downloaded with a simple Seaborn command:"""
import seaborn as sns
planets = sns.load_dataset('planets')
planets.shape
# Out:
# (1035, 6)

# %%
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
planets[['method','year']]
# Out:
#                              method  year
# 0                   Radial Velocity  2006
# 1                   Radial Velocity  2008
# 2                   Radial Velocity  2011
# 3                   Radial Velocity  2007
# 4                   Radial Velocity  2009
# 5                   Radial Velocity  2008
# 6                   Radial Velocity  2002
# 7                   Radial Velocity  1996
# 8                   Radial Velocity  2008
# 9                   Radial Velocity  2010
# 10                  Radial Velocity  2010
# 11                  Radial Velocity  2009
# 12                  Radial Velocity  2008
# 13                  Radial Velocity  1996
# 14                  Radial Velocity  2001
# 15                  Radial Velocity  2009
# 16                  Radial Velocity  1995
# 17                  Radial Velocity  1996
# 18                  Radial Velocity  2004
# 19                  Radial Velocity  2002
# 20                  Radial Velocity  2011
# 21                  Radial Velocity  2007
# 22                  Radial Velocity  2009
# 23                  Radial Velocity  2009
# 726                         Transit  2011
# 727                         Transit  2010
# 728                         Transit  2011
# 729                         Transit  2011
# 730                         Transit  2011
# 731                         Transit  2011
# 732                         Transit  2011
# 733                         Transit  2011
# 734                         Transit  2011
# 735                         Transit  2012
# 736       Transit Timing Variations  2012
# 737                         Transit  2012
# 738                         Transit  2012
# 739                         Transit  2012
# 740                         Transit  2012
# 741                         Transit  2014
# 742                 Radial Velocity  2014
# 743                         Transit  2012
# 744                         Transit  2012
# 745                         Transit  2012
# 746                         Transit  2012
# 747                         Transit  2012
# 748                         Transit  2012
# 749       Transit Timing Variations  2014
# 750                         Transit  2012
# 751                         Transit  2012
# 752                         Transit  2012
# 753                         Transit  2012
# 754                         Transit  2012
# 755                         Transit  2012
# 756                         Transit  2012
# 757                         Transit  2012
# 758                         Transit  2012
# 759                         Transit  2012
# 760                         Transit  2012
# 761                         Transit  2012
# 762                         Transit  2012
# 763                         Transit  2012
# 764                         Transit  2012
# 765                         Transit  2012
# 766                         Transit  2012
# 767                         Transit  2012
# 768                         Transit  2012
# 769                         Transit  2013
# 770                         Transit  2013
# 771                         Transit  2013
# 772                         Transit  2013
# 773                         Transit  2013
# 774                         Transit  2013
# 775                         Transit  2013
# 776                         Transit  2012
# 777                         Transit  2012
# 778                         Transit  2012
# 779                         Transit  2012
# 780                         Transit  2013
# 781                         Transit  2013
# 782                         Transit  2012
# 783                         Transit  2012
# 784                 Radial Velocity  2012
# 785                         Transit  2013
# 786                         Transit  2013
# 787   Orbital Brightness Modulation  2011
# 788   Orbital Brightness Modulation  2011
# 789                         Transit  2010
# 790                         Transit  2013
# 791                         Transit  2013
# 792   Orbital Brightness Modulation  2013
# 793                         Transit  2013
# 794                         Transit  2013
# 795                         Transit  2012
# 796                         Transit  2012
# 797                         Transit  2012
# 798                         Transit  2012
# 799                         Transit  2012
# 800                         Transit  2012
# 801                         Transit  2012
# 802                         Transit  2012
# 803                         Transit  2012
# 804                         Transit  2012
# 805                         Transit  2012
# 806                         Transit  2012
# 807                         Transit  2012
# 808                         Transit  2012
# 809                         Transit  2013
# 810                         Transit  2013
# 811                         Transit  2013
# 812                         Transit  2013
# 813       Transit Timing Variations  2013
# 814                         Transit  2013
# 815                         Transit  2013
# 816                         Transit  2013
# 817                         Transit  2013
# 818                         Transit  2013
# 819                         Transit  2013
# 820                         Transit  2013
# 821                         Transit  2013
# 822                         Transit  2013
# 823                         Transit  2013
# 824                         Transit  2013
# 825                         Transit  2013
# 826                         Transit  2013
# 827                         Transit  2013
# 828                         Transit  2014
# 829                 Radial Velocity  2014
# 830                         Transit  2014
# 831                 Radial Velocity  2014
# 832                         Transit  2014
# 833                         Transit  2014
# 834                         Transit  2014
# 835                 Radial Velocity  2014
# 836                         Transit  2014
# 837                         Transit  2014
# 838                         Transit  2014
# 839                         Transit  2014
# 840                         Transit  2014
# 841                         Transit  2014
# 842                         Transit  2014
# 843                         Transit  2014
# 844                         Transit  2013
# 845                         Transit  2014
# 846                         Transit  2014
# 964                         Transit  2009
# 965                         Transit  2008
# 966                         Transit  2010
# 967                         Transit  2008
# 968                         Transit  2008
# 969                         Transit  2008
# 970                         Transit  2009
# 971                         Transit  2008
# 972                         Transit  2009
# 973                         Transit  2009
# 974                         Transit  2009
# 975                         Transit  2009
# 976                         Transit  2009
# 977                         Transit  2010
# 978                         Transit  2010
# 979                         Transit  2010
# 980                         Transit  2010
# 981                         Transit  2010
# 982                         Transit  2010
# 983                         Transit  2010
# 984                         Transit  2010
# 985                         Transit  2010
# 986                         Transit  2010
# 987                         Transit  2010
# 988                         Transit  2010
# 989                         Transit  2011
# 990                         Transit  2011
# 991                         Transit  2010
# 992                         Transit  2010
# 993                         Transit  2011
# 994                         Transit  2010
# 995                         Transit  2012
# 996                         Transit  2011
# 997                         Transit  2011
# 998                         Transit  2011
# 999                         Transit  2011
# 1000                        Transit  2012
# 1001                        Transit  2011
# 1002                        Transit  2012
# 1003                        Transit  2011
# 1004                        Transit  2012
# 1005                        Transit  2012
# 1006                        Transit  2012
# 1007                        Transit  2012
# 1008                        Transit  2012
# 1009                        Transit  2012
# 1010                        Transit  2012
# 1011                        Transit  2012
# 1012                        Transit  2012
# 1013                        Transit  2012
# 1014                        Transit  2012
# 1015                        Transit  2012
# 1016                        Transit  2013
# 1017                        Transit  2012
# 1018                        Transit  2012
# 1019                        Transit  2012
# 1020                        Transit  2012
# 1021                        Transit  2013
# 1022                        Transit  2012
# 1023                        Transit  2012
# 1024                        Transit  2012
# 1025                        Transit  2012
# 1026                        Transit  2014
# 1027                        Imaging  2011
# 1028                        Transit  2012
# 1029                        Imaging  2012
# 1030                        Transit  2006
# 1031                        Transit  2007
# 1032                        Transit  2007
# 1033                        Transit  2008
# 1034                        Transit  2008

# %%
planets.columns
# Out:
# Index(['method', 'number', 'orbital_period', 'mass', 'distance', 'year'], dtype='object')

# %%
planets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
"""there is a convenience method describe() that computes several common aggregates for
each column and returns the result."""
planets.describe(include='all')
# Out:
#                  method       number  orbital_period        mass     distance  \
# count              1035  1035.000000      992.000000  513.000000   808.000000
# unique               10          NaN             NaN         NaN          NaN
# top     Radial Velocity          NaN             NaN         NaN          NaN
# freq                553          NaN             NaN         NaN          NaN
# mean                NaN     1.785507     2002.917596    2.638161   264.069282
# std                 NaN     1.240976    26014.728304    3.818617   733.116493
# min                 NaN     1.000000        0.090706    0.003600     1.350000
# 25%                 NaN     1.000000        5.442540    0.229000    32.560000
# 50%                 NaN     1.000000       39.979500    1.260000    55.250000
# 75%                 NaN     2.000000      526.005000    3.040000   178.500000
# max                 NaN     7.000000   730000.000000   25.000000  8500.000000
#
#                year
# count   1035.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean    2009.070531
# std        3.972567
# min     1989.000000
# 25%     2007.000000
# 50%     2010.000000
# 75%     2012.000000
# max     2014.000000

# %%
planets.isnull().any()
# Out:
# method            False
# number            False
# orbital_period     True
# mass               True
# distance           True
# year              False
# dtype: bool

# %%
planets.dropna().describe()
# Out:
#           number  orbital_period        mass    distance         year
# count  498.00000      498.000000  498.000000  498.000000   498.000000
# mean     1.73494      835.778671    2.509320   52.068213  2007.377510
# std      1.17572     1469.128259    3.636274   46.596041     4.167284
# min      1.00000        1.328300    0.003600    1.350000  1989.000000
# 25%      1.00000       38.272250    0.212500   24.497500  2005.000000
# 50%      1.00000      357.000000    1.245000   39.940000  2009.000000
# 75%      2.00000      999.600000    2.867500   59.332500  2011.000000
# max      6.00000    17337.500000   25.000000  354.000000  2014.000000

# %% [markdown]
# <pre><b>Listing of Pandas aggregation methods</b>
# Aggregation           Description
# count()               Total number of items
# first(), last()       First and last item
# mean(), median()      Mean and median
# min(), max()          Minimum and maximum
# std(), var()          Standard deviation and variance
# mad()                 Mean absolute deviation
# prod()                Product of all items
# sum()                 Sum of all items</pre>

# %% [markdown]
# ###### Group by: Split, Apply and Combine
# <img src="Group by.png">

# %%
df = pd.DataFrame({'key': ['A', 'B', 'C', 'A', 'B', 'C'],
'data': range(1,7)}, columns=['key', 'data'])

# %%
df
# Out:
#   key  data
# 0   A     1
# 1   B     2
# 2   C     3
# 3   A     4
# 4   B     5
# 5   C     6

# %%
df.groupby('key')

# %%
df.groupby('key').sum()
# Out:
#      data
# key
# A       5
# B       7
# C       9

# %%
planets.groupby('method')

# %%
#column indexing
planets.groupby('method')['orbital_period']

# %%
planets.groupby('method')['orbital_period'].median()
# Out:
# method
# Astrometry                         631.180000
# Eclipse Timing Variations         4343.500000
# Imaging                          27500.000000
# Microlensing                      3300.000000
# Orbital Brightness Modulation        0.342887
# Pulsar Timing                       66.541900
# Pulsation Timing Variations       1170.000000
# Radial Velocity                    360.200000
# Transit                              5.714932
# Transit Timing Variations           57.011000
# Name: orbital_period, dtype: float64

# %%
df = pd.read_json('2024.json')
df.shape
# Out:
# (1000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1000 non-null   object
#  1   code            1000 non-null   object
#  2   logo            1000 non-null   object
#  3   rank            1000 non-null   object
#  4   region          1000 non-null   object
#  5   region_code     1000 non-null   object
#  6   region_ranking  1000 non-null   object
#  7   score           100 non-null    float64
#  8   breakdown       1000 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 70.4+ KB

# %%
df.head(10)
# Out:
#                                           name  \
# 0                           Harvard University
# 1                          Stanford University
# 2  Massachusetts Institute of Technology (MIT)
# 3                      University of Cambridge
# 4           University of California, Berkeley
# 5                         University of Oxford
# 6                         Princeton University
# 7           California Institute of Technology
# 8                          Columbia University
# 9                        University of Chicago
#
#                                         code                logo rank  \
# 0                         harvard-university  logo/032bd1b77.png    1
# 1                        stanford-university  logo/13de8913b.png    2
# 2  massachusetts-institute-of-technology-mit  logo/79165fd8b.png    3
# 3                    university-of-cambridge  logo/8d9861b69.png    4
# 4          university-of-california-berkeley  logo/0ff179fb8.png    5
# 5                       university-of-oxford  logo/c1d967477.png    6
# 6                       princeton-university  logo/b1dad5288.png    7
# 7         california-institute-of-technology  logo/c956f3d98.png    8
# 8                        columbia-university  logo/ce3421720.png    8
# 9                      university-of-chicago  logo/b4f6eec47.png   10
#
#            region region_code region_ranking  score  \
# 0   United States          us              1  100.0
# 1   United States          us              2   75.6
# 2   United States          us              3   69.5
# 3  United Kingdom          gb              1   67.8
# 4   United States          us              4   62.0
# 5  United Kingdom          gb              2   60.0
# 6   United States          us              5   58.8
# 7   United States          us            6-7   55.1
# 8   United States          us            6-7   55.1
# 9   United States          us              8   54.4
#
#                                            breakdown
# 0  {'Alumni': 100, 'Award': 97.1, 'HiCi': 100, 'N...
# 1  {'Alumni': 45.3, 'Award': 88.1, 'HiCi': 73.1, ...
# 2  {'Alumni': 71.9, 'Award': 82.8, 'HiCi': 55.2, ...
# 3  {'Alumni': 78.2, 'Award': 90.8, 'HiCi': 45.1, ...
# 4  {'Alumni': 65.3, 'Award': 76.5, 'HiCi': 46.9, ...
# 5  {'Alumni': 49.5, 'Award': 59.7, 'HiCi': 51.3, ...
# 6  {'Alumni': 61.2, 'Award': 100, 'HiCi': 26, 'N&...
# 7  {'Alumni': 55.7, 'Award': 63.4, 'HiCi': 29.8, ...
# 8  {'Alumni': 59.4, 'Award': 63.2, 'HiCi': 42.7, ...
# 9  {'Alumni': 59, 'Award': 84.5, 'HiCi': 32.5, 'N...

# %%
import pandas as pd
import sqlite3

# Load the CSV file into a pandas DataFrame
df = pd.read_csv('diabetes_data_all_patient.csv')

# Create a connection to SQLite database
conn = sqlite3.connect('my_database.db')

# Write the data to a table named 'diabetes'
df.to_sql('diabetes', conn, if_exists='replace', index=False)

# Close the connection
conn.close()

# %%
# Connect to the SQLite database
conn = sqlite3.connect('my_database.db')

# Create a cursor object
cursor = conn.cursor()

# Execute a query to get the table names
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

# Fetch and print the list of tables
tables = cursor.fetchall()
print(tables)

# Close the connection
conn.close()
# Out:
# [('diabetes',)]

# %%
# Connect to the SQLite database
conn = sqlite3.connect('my_database.db')

# Write a SQL query to fetch the data
query = "SELECT * FROM diabetes"

# Read the data into a pandas DataFrame
df = pd.read_sql_query(query, conn)

# Close the database connection
conn.close()

# Display the DataFrame
print(df)
# Out:
#        Unnamed: 0  patient_id        date   time  code value
# 0               0           1  04-21-1991   9:09    58   100
# 1               1           1  04-21-1991   9:09    33     9
# 2               2           1  04-21-1991   9:09    34    13
# 3               3           1  04-21-1991  17:08    62   119
# 4               4           1  04-21-1991  17:08    33     7
# ...           ...         ...         ...    ...   ...   ...
# 29325         336          70  05-09-1989  08:00    33   1.0
# 29326         337          70  05-09-1989  08:00    34   7.0
# 29327         338          70  05-10-1989  08:00    34   7.0
# 29328         339          70  05-11-1989  08:00    34   7.0
# 29329         340          70  05-12-1989  08:00    34   7.0
#
# [29330 rows x 6 columns]

# %%
#%pip install jupytext
#!jupytext --to notebook seaborn_visualization_examples.py

# %%
#%pip install jupytext
#!jupytext --to notebook plotly_visualization_examples.py
